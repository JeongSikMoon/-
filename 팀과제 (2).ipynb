# %%
import random as rd

diet_food = ['토마토 달걀볶음','바나나 쉐이크','닭가슴살 샐러드','두부 스테이크','해독주스','리코타 치즈','곤약국수','단호박 스프','양배추 스프'] 
speed_food = ['오믈렛','치킨마요 덮밥','계란찜','연어덮밥','떡국','만둣국','김치 볶음밥','오차즈케','누룽지죽']
brunch = ['팬케이크','프리타타','에그 베네딕트','몬테 크리스토','그로크무슈/마담','조개스프','샐러드 파스타','불고기 브리또','프렌치 토스트']
lunch_box = ['김밥','유부초밥','캘리포니아롤','바게트버거','밥버거','샌드위치','볶음밥','스팸 무스비','오니기리']
nutrition_food = ['전복죽','추어탕','장어구이','더덕구이','삼계탕','낙지연포탕','훈제오리부추무침','닭죽','갈비탕']
Hangover_Soup = ['대파라면','콩나물 해장국','북엇국','홍합탕','김치 콩나물죽','토마토 주스','굴국밥','오징어 무국','순두부 찌개']
Snack = ['토스트','또띠아피자','떡꼬치','쿠키',' 떡볶이','호떡','샌드위치','시리얼','팝시클']
guest_food = ['깐풍만두','닭가슴살냉채','잡채','찜닭','갈비찜','월남쌈','칠리새우','투움바파스타','라자냐']


# dict1 = 손님대접
guest_dict = {'1.깐풍만두':'https://www.youtube.com/watch?v=24SO6nTTQsE',
              '2.닭가슴살냉채':'https://www.youtube.com/watch?v=gwRLn6JvVMg',
              '3.잡채':'https://www.youtube.com/watch?v=j6z0IX-c3tQ',
              '4.찜닭':'https://www.youtube.com/watch?v=WYH6urUbxDo',
              '5.갈비찜':'https://www.youtube.com/watch?v=S_j12UeNYDU',
              '6.월남쌈':'https://www.youtube.com/watch?v=1gm1uq2Z9MI',
              '7.칠리새우':'https://www.youtube.com/watch?v=5mRFdL0j4hM',
              '8.투움바파스타':'https://www.youtube.com/watch?v=yiSai1bApTA',
              '9.라자냐':'https://www.youtube.com/watch?v=twzllRRCjN4'}
#dic2 = 해장
hangover_soup_dict = {'1.대파라면':'https://www.youtube.com/watch?v=ozxtNoUWOuU',
                      '2.콩나물해장국':'https://www.youtube.com/watch?v=QI4HQlOYh3w',
                      '3.북엇국':'https://www.youtube.com/watch?v=TMZfTJnR1ww',
                      '4.홍합탕':'https://www.youtube.com/watch?v=WPvlQhABVvg',
                      '5.김치 콩나물죽':'https://www.youtube.com/watch?v=psnt67_ODEI',
                      '6.토마토주스':'https://www.youtube.com/watch?v=2qxJvaGYr8c',
                      '7.굴국밥':'https://www.youtube.com/watch?v=xnMWH7AkT6Q',
                      '8.오징어 무국':'https://www.youtube.com/watch?v=f0kVco1_VXg',
                      '9.순두부 찌개':'https://www.youtube.com/watch?v=GP8_7D5eM6A'}
#dict3=간식/야식
snack_dict={'1.토스트':'https://www.youtube.com/watch?v=KA5ZaFk87NU',
            '2.또띠아피자':'https://www.youtube.com/watch?v=Qz7TLmI51v4',
            '3.떡꼬치':'https://www.youtube.com/watch?v=xLG6OGr6TRw',
            '4.쿠키':'https://www.youtube.com/watch?v=B0JIeAZ_nHY&t=551s',
                   '4.연어덮밥':'https://www.youtube.com/watch?v=ysmb1xRXvhs',
                   '5.떡국':'https://www.youtube.com/watch?v=u_MUG2jHy9k',
                   '6.만둣국':'https://www.youtube.com/watch?v=Q7UApIHC5Hk',
                   '7.김치 볶음밥':'https://www.youtube.com/watch?v=R6IT_f0XPT8',
                   '8.오차즈케':'https://www.youtube.com/watch?v=civi39aSyyk',
                   '9.누룽지죽':'https://www.youtube.com/watch?v=SlHYD2o77wU'}
# dict8 = 브런치
brunch_dict = {'1.팬케이크' : 'https://www.youtube.com/watch?v=QXCCBGcKlLc',
               '2.프리타타' : 'https://www.youtube.com/watch?v=q3oPfnr5d80',
               '3.에그베네딕트' : 'https://www.youtube.com/watch?v=_l7FLUtD338',
               '4.몬테크리스토' : 'https://www.youtube.com/watch?v=RsQAoTV6xsc',
               '5.크로크무슈/마담' : 'https://www.youtube.com/watch?v=vc-LiSjgktw',
               '6.조개스프' : 'https://www.youtube.com/watch?v=QeZ8IvJAMMs',
               '7.샐러드파스타' : 'https://www.youtube.com/watch?v=FzUXVYSNZrk',
               '8.불고기브리또' : 'https://www.youtube.com/watch?v=rsTX1G8ll9I',
               '9.프렌치토스트' : 'https://www.youtube.com/watch?v=nrWC6g6Djr8'}

situation_list = ['1. 손님대접', '2. 해장', '3. 간식/야식', '4. 도시락', '5. 영양식' , '6. 식이조절', 
                  '7. 초스피드', '8. 브런치', '9. 종료']
# print(situation_list) 처음 보여주는 리스트

situation_list_1 =['guest_food', 'Hangover_Soup', 'Snack', 'lunch_box', 'nutrition_food',
                   'diet_food', 'speed_food', 'brunch']
# print(situation_list_1)

situation_dict = {'guest_food':guest_dict,'Hangover_Soup':hangover_soup_dict, 'Snack':snack_dict, 
                 'lunch_box':lunch_box_dict, 'nutrition_food':nutrition_dict, 'diet_food':diet_food_dict, 
                  'speed_food':speed_food_dict,'brunch':brunch_dict}

# %%
while 1: #1번째 while문
    print(situation_list) #상황별 항목을 출력해준다.
    situation = int(input('현재 상황 번호를 숫자로 입력하세요? >> '))-1
    
#situation 변수안에 int type으로 input 을 받는다.     
#situation 리스트는 인덱스는 0번부터 시작하기 때문에 항목중에 1.손님대접 선택시 내부적으로 값이 0 이여서 
#
    
                                                               
    
    if situation <= 7:

#입력된 값이 7포함된 이하의 숫자를 눌렀을때

        title = situation_list_1[situation]
#입력받은 situation 변수를 situation_list_1 리스트의 인덱스로 사용하여
#title 변수에 넣어준다.
        print(title)
#title 출력        


        menu = situation_dict[title]
#title 변수를 situation_dict의 인덱스로 사용하여 menu변수에 넣어준다.
#현재 title은 리스트로 가지고있고 situation_dict의 key값을 찾는다.
        menu_show = list(menu.keys())
#상황 선택시 상황에 해당하는 음식들 저장   
        menu_keys = list(menu.keys())
#상황 선택시 음식의 이름을 저장       
        menu_values = list(menu.values())
#상황 선택시 음식의 레시피 링크를 저장
        option = ['10. 랜덤', '11. 뒤로가기']
        menu_show.extend(option)
#option항목을 추가

        while 1: #2번째 while문
            
            print(menu_show)
            #메뉴를 나타내는 항목이 출력된다.
            menu_select = int(input('메뉴를 숫자로 입력하세요? >> '))-1
#메뉴항목에서 선택한 값이 menu변수에 들어간다.            
            
            if menu_select <= 8:
#선택한 항목중에서 8포함 이하 숫자를 누르면 
                print(menu_keys[menu_select], menu_values[menu_select])
#situation_dict의 values값 - 음식들 딕셔너리로 가서 key,value값을 출력한다.
            elif menu_select == 9:
#9번 선택시        
                print('****메뉴 랜덤 출력****')
#다음 문자열 출력후    
                rds = rd.randrange(0, 9)
#랜덤 함수를 통해 현재 선택된 상황별 메뉴 중에서 음식 딕셔너리에있는 음식을 선택
                print(menu_keys[rds], menu_values[rds])
#선택된 음식의 key,value가 출력된다. (음식이름,레시피 링크)    
            elif menu_select == 10:
#10번 선택시        
                break
#break문을 통해 2번째 while문을 빠져나온다.    
            else:
#그외의 입력이 들어오면         
                pass
#현재 상황에서 아무 동작하지않고 다음코드를 실행한다.즉,2번째 while문을 계속 실행
    elif situation == 8:
#2번째 while문을 빠져나온 후 종료를 선택하면         
        print('종료')
#종료를 출력하고     
        break
#1번째 while문을 빠져나온후 종료된다.
    else:
        pass
#현재 1번째 while문을 계속 실행한다.
# Out:
# ['1. 손님대접', '2. 해장', '3. 간식/야식', '4. 도시락', '5. 영양식', '6. 식이조절', '7. 초스피드', '8. 브런치', '9. 종료']
# 현재 상황 번호를 숫자로 입력하세요? >> 1
# guest_food
# ['1.깐풍만두', '2.닭가슴살냉채', '3.잡채', '4.찜닭', '5.갈비찜', '6.월남쌈', '7.칠리새우', '8.투움바파스타', '9.라자냐', '10. 랜덤', '11. 뒤로가기']
# 메뉴를 숫자로 입력하세요? >> 10
# ****메뉴 랜덤 출력****
# 9.라자냐 https://www.youtube.com/watch?v=twzllRRCjN4
# ['1.깐풍만두', '2.닭가슴살냉채', '3.잡채', '4.찜닭', '5.갈비찜', '6.월남쌈', '7.칠리새우', '8.투움바파스타', '9.라자냐', '10. 랜덤', '11. 뒤로가기']
# 메뉴를 숫자로 입력하세요? >> 8
# 8.투움바파스타 https://www.youtube.com/watch?v=yiSai1bApTA
# ['1.깐풍만두', '2.닭가슴살냉채', '3.잡채', '4.찜닭', '5.갈비찜', '6.월남쌈', '7.칠리새우', '8.투움바파스타', '9.라자냐', '10. 랜덤', '11. 뒤로가기']
# 메뉴를 숫자로 입력하세요? >> 11
# ['1. 손님대접', '2. 해장', '3. 간식/야식', '4. 도시락', '5. 영양식', '6. 식이조절', '7. 초스피드', '8. 브런치', '9. 종료']
# 현재 상황 번호를 숫자로 입력하세요? >> 3
# Snack
# ['1.토스트', '2.또띠아피자', '3.떡꼬치', '4.쿠키', '5.떡볶이', '6.호떡', '7.샌드위치', '8.시리얼', '9.팝시클', '10. 랜덤', '11. 뒤로가기']
# 메뉴를 숫자로 입력하세요? >> 5
# 5.떡볶이 https://www.youtube.com/watch?v=e4IiFXmaW5Y
# ...
